# %% [markdown]
# # Análisis Exploratorio de Datos (EDA) - Detección de Cáncer de Mama **Proyecto:** Capstone TAV 2026 **Autor:** [Karla A. Bravo]

# %%
import pandas as pd
import numpy as np

from google.colab import drive
drive.mount('/content/drive')

path = '/content/drive/MyDrive/Dataset_ Wisconsin_ Breast_ Cancer/data.csv'
df = pd.read_csv(path)

df.drop(columns=['id', 'Unnamed 32'], inplace=True, errors='ignore')

print ("Dimensiones del dataset:", df.shape)
df.head()
# Out:
# Mounted at /content/drive
# Dimensiones del dataset: (569, 32)
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df['diagnosis'] = df['diagnosis'].map({'M': 1, 'B': 0})

plt.figure(figsize=(8, 5))
sns.countplot(x='diagnosis', data=df, palette='magma')
plt.title('Distribución de Diagnósticos (0: Benigno, 1: Maligno)')
plt.xlabel('Diagnóstico')
plt.ylabel('Cantidad de Casos')
plt.show()

plt.figure(figsize=(20, 15))

correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm', linewidths=0.5)
plt.title('Matriz de Correlación de Características Morfológicas')
plt.show()
# Out:
# /tmp/ipython-input-1539321329.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='diagnosis', data=df, palette='magma')
